# %% [markdown]
# <img src="./Logo.jpg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo Semanal 0
# ## Introduccion a Jupyter Notebooks
# ### Juan Manuel Ronchetti

# %% [markdown]
# A continuacion se encuentra un codigo de prueba para experimentar con las posibilidades del Jupyter Notebooks.

# %% [markdown]
# ### Sistema Subamortiguado

# %%
# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

from scipy.signal import TransferFunction
import numpy as np
import matplotlib.pyplot as plt


# las librerías que usarremos las cargamos solo una vez.

# %%
#%%  Inicialización de librerías 

plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

#%%  Fin - Inicialización de librerías

# %%
w0 = 1
qq = np.sqrt(2)/2

my_tf = TransferFunction( [w0**2], [1, w0/qq, w0**2] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ### Sistema Sobreamortiguado

# %%
#%% Edito el tamaño de los graficos:

fig_sz_x = 10
fig_sz_y = 5
fig_dpi = 80 # dpi
fig_font_size = 12

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

#%% Nueva transferencia:

w0 = 1
qq = 1/3

my_tf = TransferFunction( [w0**2], [1, w0/qq, w0**2] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# # Modificaciones Realizadas:
#  * Modificado el titulo
#  * Agregado logo de UTN desde imagen jpg
#  * Eliminadas algunas celdas
#  * Agregada una nueva celda donde se modifico la transferencia con un Q=1/3 y se modifico a su vez el tamaño de los graficos
